# %% [markdown]
# <a href="https://colab.research.google.com/github/braulioalda4-code/nuevo_repositorio/blob/main/Examen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nombre de los integrantes: Braulio Aldahír Rodríguez Espinosa
# EXAMEN UNIDAD 1

# %%
# Celda para cargar el dataset
import pandas as pd
# Cargar el dataset
reviews = pd.read_csv("datasets/harvard_reviews.csv")

# %% [markdown]
# Ejercicio 1

# %%
# Ejercicio 1: Selecciona la columna text del dataframe reviews y asignalo a una variable llamada col_texto
col_texto = reviews['text']
# Pregunta complementaria ¿qué tipo de objeto es col_texto?
print(type(col_texto))
# Respuesta
# Out:
# <class 'pandas.core.series.Series'>

# %% [markdown]
# Ejercicio 2

# %%
# Ejercicio 2: Selecciona el primer valor de la columna
primer_texto = reviews['text']
# Seleccionado primer texto
primer_texto
# Out:
# 0       Good thanks for everything good work group 👍 h...
# 1       Harvard University was founded in 1636 and is ...
# 2       We did a walk around most of the Harvard Campu...
# 3       We had a walk through the university grounds w...
# 4       Finally made it to Harvard!!  This iconic univ...
#                               ...
# 3179    wenn man in boston ist hat manmeistens zeit au...
# 3180    Von der Führung der Harvard University erhofft...
# 3181    da vedere questa città, studio sede di una del...
# 3182    Hallo,\nich habe ein Jahr an der Harvard Law S...
# 3183    とても歴史のある素敵な建物です。ハーバードスクエアーの駅の近くから無料のツアー（英語）をハー...
# Name: text, Length: 3184, dtype: object

# %% [markdown]
# Ejercicio 3

# %%
# Ejercicio 3: Selecciona la primera fila de datos
primera_fila = reviews
# Seleccionado
primera_fila
# Out:
#                  published_date published_platform  rating    type  \
# 0     2023-12-28T08:02:14-05:00             Mobile       5  review
# 1     2023-12-12T00:38:26-05:00            Desktop       4  review
# 2     2023-12-10T08:21:35-05:00             Mobile       3  review
# 3     2023-11-07T21:20:21-05:00            Desktop       4  review
# 4     2023-10-02T17:40:42-04:00            Desktop       5  review
# ...                         ...                ...     ...     ...
# 3179  2010-10-29T05:47:57-04:00            Desktop       3  review
# 3180  2010-08-23T06:08:51-04:00            Desktop       3  review
# 3181  2010-08-23T00:06:41-04:00            Desktop       5  review
# 3182  2010-06-03T07:37:36-04:00            Desktop       5  review
# 3183  2009-09-27T16:39:18-04:00            Desktop       5  review
#
#       helpful_votes                                              title  \
# 0                 0                 Best classes and good environment
# ...

# %% [markdown]
# Ejercicio 4

# %%
# Ejercicio 4: Selecciona los 10 primeros valores de la columna `title`
primeros_titulos = reviews['title'].head(10)
# Imprimir  al titulo que seleccionamos
primeros_titulos
# Out:
# 0                   Best classes and good environment
# 1                                   Harvard University
# 2                                   Walk around campus
# 3                       Interesting Harvard University
# 4    Lovely university campus has many historic and...
# 5       Interesting walk around campus grounds & river
# 6                                  Inspirational place
# 7               Harvard University student guided tour
# 8                            Beautiful historic campus
# 9                                          Nice campus
# Name: title, dtype: object

# %% [markdown]
# Ejercicio 5

# %%
# Ejercicio 5: Selecciona los registros con índices 1, 2, 3, 5 y 8
reviews_filtradas = reviews.loc[[1, 2, 3, 5, 8]]
reviews_filtradas
# Out:
#               published_date published_platform  rating    type  \
# 1  2023-12-12T00:38:26-05:00            Desktop       4  review
# 2  2023-12-10T08:21:35-05:00             Mobile       3  review
# 3  2023-11-07T21:20:21-05:00            Desktop       4  review
# 5  2023-09-29T08:44:17-04:00            Desktop       4  review
# 8  2023-07-02T11:55:51-04:00            Desktop       4  review
#
#    helpful_votes                                           title  \
# 1              0                              Harvard University
# 2              0                              Walk around campus
# 3              0                  Interesting Harvard University
# 5              0  Interesting walk around campus grounds & river
# 8              2                       Beautiful historic campus
#
#                                                 text  rating_europe
# 1  Harvard University was founded in 1636 and is ...              8
# ...

# %% [markdown]
# Ejercicio 6

# %%
# Ejercicio 6: Columnas específicas para índices específicos
df = reviews.loc[[0, 1, 10, 100], ['published_platform', 'rating', 'type', 'helpful_votes']]
df
# Out:
#     published_platform  rating    type  helpful_votes
# 0               Mobile       5  review              0
# 1              Desktop       4  review              0
# 10              Mobile       4  review              0
# 100             Mobile       3  review              2

# %% [markdown]
# Ejercicio 7

# %%
# Ejercicio 7: Columnas title y text de los 100 primeros registros
df = reviews.loc[:99, ['title', 'text']]
print(df.head())
# Out:
#                                                title  \
# 0                 Best classes and good environment
# 1                                 Harvard University
# 2                                 Walk around campus
# 3                     Interesting Harvard University
# 4  Lovely university campus has many historic and...
#
#                                                 text
# 0  Good thanks for everything good work group 👍 h...
# 1  Harvard University was founded in 1636 and is ...
# 2  We did a walk around most of the Harvard Campu...
# 3  We had a walk through the university grounds w...
# 4  Finally made it to Harvard!!  This iconic univ...

# %% [markdown]
# Ejercicio 8

# %%
# Ejercicio 8: Registros donde rating > 3
harvard_rating = reviews[reviews['rating'] > 3]
print(harvard_rating.head())
# Out:
#               published_date published_platform  rating    type  \
# 0  2023-12-28T08:02:14-05:00             Mobile       5  review
# 1  2023-12-12T00:38:26-05:00            Desktop       4  review
# 3  2023-11-07T21:20:21-05:00            Desktop       4  review
# 4  2023-10-02T17:40:42-04:00            Desktop       5  review
# 5  2023-09-29T08:44:17-04:00            Desktop       4  review
#
#    helpful_votes                                              title  \
# 0              0                 Best classes and good environment
# 1              0                                 Harvard University
# 3              0                     Interesting Harvard University
# 4              0  Lovely university campus has many historic and...
# 5              0     Interesting walk around campus grounds & river
#
#                                                 text  rating_europe
# 0  Good thanks for everything good work group 👍 h...             10
# ...

# %% [markdown]
# Ejercicio 9

# %%
# Ejercicio 9: Rating > 3 y plataforma móvil
harvard_mobile = reviews[(reviews['rating'] > 3) & (reviews['published_platform'] == 'Mobile')]
print(harvard_mobile.head())
# Out:
#                published_date published_platform  rating    type  \
# 0   2023-12-28T08:02:14-05:00             Mobile       5  review
# 10  2023-05-24T11:38:11-04:00             Mobile       4  review
# 13  2023-04-03T15:02:44-04:00             Mobile       4  review
# 14  2023-03-14T12:11:55-04:00             Mobile       5  review
# 22  2022-10-30T08:02:03-04:00             Mobile       5  review
#
#     helpful_votes                                       title  \
# 0               0          Best classes and good environment
# 10              0                          Harvard University
# 13              0        Start saving for your grandchildren!
# 14              0                        The American College
# 22              0  Great tour of Harvard that I finally took.
#
#                                                  text
# 0   Good thanks for everything good work group 👍 h...
# 10  They have great accessibility features such as...
# ...

# %% [markdown]
# Ejercicio 10

# %%
# Ejercicio 10: Añadir columna rating_europe (rating * 2)
reviews['rating_europe'] = reviews['rating'] * 2
print(reviews[['rating', 'rating_europe']].head())
# Out:
#    rating  rating_europe
# 0       5             10
# 1       4              8
# 2       3              6
# 3       4              8
# 4       5             10

# %% [markdown]
# Autoevaluación

# %%
# Autoevaluación
print("Mi autoevaluación para el Tema 1 es: 8")
print("He comprendido bien los conceptos de selección y filtrado de datos en pandas, pero necesito practicar más el manejo de condiciones complejas.")
# Out:
# Mi autoevaluación para el Tema 1 es: 8
# He comprendido bien los conceptos de selección y filtrado de datos en pandas, pero necesito practicar más el manejo de condiciones complejas.
